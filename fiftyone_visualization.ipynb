# %%
import numpy as np
import PIL
import umap
import pandas as pd
import json
import glob
from pytorch_metric_learning import distances, losses, miners, reducers
import torch.nn as nn
import os
import matplotlib.pyplot as plt
import torch
import torchvision
from torchvision import models
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
from tqdm import tqdm
from pytorch_metric_learning import losses, testers
from pytorch_metric_learning.utils.accuracy_calculator import AccuracyCalculator
from pytorch_metric_learning.distances import LpDistance,CosineSimilarity
from pytorch_metric_learning.utils.inference import CustomKNN
# %matplotlib inline
import torch
import torch.nn as nn
from matplotlib import pyplot as plt
import numpy as np
import torchvision
import torchvision.datasets as datasets
import torchvision.models as models
from torchvision import transforms
import torch.optim as optim
import time
import tqdm as tqdm
from torch.autograd import Variable

# %%
config = {
    'name':'cub_triplet_loss_epshn_resnet50_sgd_aug',
    'dataset':'CUB_200_2011',
    'random_seed':42,
    'model_architecture':'resnet50',
    'embedding_dim':128,
    'distance':'cosine',
    'image_height':224,
    'image_width':224,
    'train_test_split':0.2,
    'class_split':0.1,
    'batch_size':128,
    'optimizer':'sgd',
    'learning_rate':0.001,
    'num_epochs':100,
    'loss':'NTXentLoss',
    'miner':'epshn',
    'reducer':0,
    'metric':'precision_at_1',
    'model_save_path':'models/cub_triplet_loss_epshn_resnet50_sgd_aug',
    'temperature': 0.1
}

# %%
np.random.seed(config['random_seed'])
torch.manual_seed(config['random_seed'])
torch.cuda.manual_seed(config['random_seed'])
torch.backends.cudnn.deterministic = False

# %%
# print(models.resnet18())
class ResNetFeatrueExtractor50(nn.Module):
    def __init__(self, pretrained = True):
        super(ResNetFeatrueExtractor50, self).__init__()
        self.model = models.resnet50(pretrained=pretrained)
        self.model.fc = nn.Linear(2048, config['embedding_dim'])

    def forward(self, x):
        x = self.model(x)
        return F.normalize(x)

# %%
device = torch.device("cuda")

mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

# create train and test transforms
transform = transforms.Compose(
    [
        transforms.Resize((config['image_height'], config['image_width'])),
        transforms.ToTensor(),
        transforms.Normalize(mean, std),
    ]
)

batch_size = 128

# %%
def tra_transforms(imgsize, RGBmean, RGBstdv):
    return transforms.Compose([transforms.Resize(int(imgsize*1.1)),
                                 transforms.RandomCrop(imgsize),
                                 transforms.RandomHorizontalFlip(),
                                 transforms.ToTensor(),
                                 transforms.Normalize(RGBmean, RGBstdv)])

def eva_transforms(imgsize, RGBmean, RGBstdv):
    return transforms.Compose([transforms.Resize(imgsize),
                                 transforms.CenterCrop(imgsize),
                                 transforms.ToTensor(),
                                 transforms.Normalize(RGBmean, RGBstdv)])

# %%
train_transform = tra_transforms(224,mean,std)
test_transform = eva_transforms(224,mean,std)

# %%
with open('CUB_200_2011/classes.txt','r') as f:
    classes = f.readlines()
classes = [i.replace('\n','') for i in classes]
classes = [i.split(' ')[1] for i in classes]
class_dict = {k:v for k,v in zip(classes,range(200))}

# %%
image_paths = []
labels = []
for folder_path,i in class_dict.items():
    folder_images = glob.glob('CUB_200_2011/images/'+'/'+str(folder_path)+'/*')
    image_paths.extend(folder_images)
    labels.extend([i]*len(folder_images))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_paths, labels, test_size=config['train_test_split'],
                                                    stratify=labels,
                                                    random_state=config['random_seed'])

# %%
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 9430 2358 9430 2358

# %%
model = torch.load('models/cub_triplet_loss_epshn_resnet50_sgd_aug_180.pth',map_location='cuda')

# %%
model.eval()
# Out:
# ResNetFeatrueExtractor50(
#   (model): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=2048, out_features=128, bias=True)
#   )
# )

# %%
def extract_category(path):
    return path.split('/')[-2]
    
sorted_test_paths = sorted(X_test, key=extract_category)
sorted_train_paths = sorted(X_train, key=extract_category)

# %%
rev_class_dict = {v:k for k,v in class_dict.items()}

# %%
import fiftyone as fo
import numpy as np
import fiftyone.brain as fob
import fiftyone.zoo as foz
from fiftyone import ViewField as F

# %%
name = "CUB-200"
dataset_dir = "CUB_200_2011/images/"
# Create the dataset
dataset = fo.Dataset.from_dir(
    dataset_dir=dataset_dir,
    dataset_type=fo.types.ImageClassificationDirectoryTree,
    name=name,
)

# View summary info about the dataset
print(dataset)

# Print the first few samples in the dataset
print(dataset.head())
# Out:
#  100% |█████████████| 11788/11788 [1.9s elapsed, 0s remaining, 6.4K samples/s]
# Name:        CUB-200
# Media type:  image
# Num samples: 11788
# Persistent:  False
# Tags:        []
# Sample fields:
#     id:           fiftyone.core.fields.ObjectIdField
#     filepath:     fiftyone.core.fields.StringField
#     tags:         fiftyone.core.fields.ListField(fiftyone.core.fields.StringField)
#     metadata:     fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.metadata.ImageMetadata)
#     ground_truth: fiftyone.core.fields.EmbeddedDocumentField(fiftyone.core.labels.Classification)
# [<Sample: {
#     'id': '6639187385c213e6d9a3e5be',
#     'media_type': 'image',
#     'filepath': '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0001_796111.jpg',
#     'tags': [],
#     'metadata': None,
#     'ground_truth': <Classification: {
#         'id': '6639187385c213e6d9a3e5bd',
#         'tags': [],
#         'label': '001.Black_footed_Albatross',
#         'confidence': None,
#         'logits': None,
#     }>,
# }>, <Sample: {
#     'id': '6639187385c213e6d9a3e5c7',
#     'media_type': 'image',
#     'filepath': '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0002_55.jpg',
#     'tags': [],
#     'metadata': None,
#     'ground_truth': <Classification: {
#         'id': '6639187385c213e6d9a3e5bf',
#         'tags': [],
#         'label': '001.Black_footed_Albatross',
#         'confidence': None,
#         'logits': None,
#     }>,
# }>, <Sample: {
#     'id': '6639187385c213e6d9a3e5c8',
#     'media_type': 'image',
#     'filepath': '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0003_796136.jpg',
#     'tags': [],
#     'metadata': None,
#     'ground_truth': <Classification: {
#         'id': '6639187385c213e6d9a3e5c0',
#         'tags': [],
#         'label': '001.Black_footed_Albatross',
#         'confidence': None,
#         'logits': None,
#     }>,
# }>]

# %%
with open('CUB_200_2011/classes.txt','r') as f:
    classes = f.readlines()
classes = [i.replace('\n','') for i in classes]
classes = [i.split(' ')[1] for i in classes]
class_dict = {k:v for k,v in zip(classes,range(200))}

# %%
filepaths = dataset.values('filepath')
# Out:
# ['/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0001_796111.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0002_55.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0003_796136.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0005_796090.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0006_796065.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0007_796138.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0008_796083.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0009_34.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0010_796097.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0014_89.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0016_796067.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0017_796098.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0019_796104.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0023_796059.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0024_796089.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0025_796057.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0026_796095.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0031_100.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0032_796115.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0033_796086.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0035_796140.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0036_796127.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0037_796120.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0038_212.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0039_796132.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0040_796066.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0041_796108.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0042_796071.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0045_796129.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0046_18.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0047_796064.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0049_796063.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0050_796125.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0051_796103.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0053_796109.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0056_796078.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0057_796106.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0058_796074.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0060_796076.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0061_796082.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0063_796141.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0064_796101.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0065_796068.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0067_170.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0068_796135.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0069_796139.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0071_796113.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_0074_59.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/001.Black_footed_Albatross/Black_Footed_Albatross_
jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0066_17803.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0072_17159.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0074_18339.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0075_17946.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0078_17181.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0079_19044.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0081_17291.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0082_17875.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0083_18042.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0084_17576.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0085_19162.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0089_18005.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0092_17591.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0093_17676.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0094_17165.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0095_18108.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0097_17396.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0102_17808.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0103_17425.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0104_17122.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/017.Cardinal/Cardinal_0105_19045.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0001_796797.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0002_796827.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0003_796822.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0004_796804.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0005_19411.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0006_796823.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0007_19424.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0008_796789.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0009_796795.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0010_19436.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0011_796815.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0012_796802.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0013_19428.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0014_19425.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0015_796808.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0016_796803.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0018_796800.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0019_796788.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0020_796794.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0021_796798.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0022_796821.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0023_796793.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0024_796791.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0025_796819.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0026_796818.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0027_796796.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0028_796813.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0029_796825.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0030_796801.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0031_796806.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0032_796828.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0033_796805.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0034_19437.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0035_796799.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0036_19406.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0037_796810.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0039_796811.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0040_796820.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0041_796807.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0042_19430.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0044_796809.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0045_796814.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0046_19399.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0047_19400.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/018.Spotted_Catbird/Spotted_Catbird_0048_796817.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/019.Gray_Catbird/Gray_Catbird_0001_20695.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/019.Gray_Catbird/Gray_Catbird_0002_21395.jpg',
#  '/home/pranav/embedding_classification/CUB_200_2011/images/019.Gray_Catbird/Gray_Catbird_0006_20867.jpg',
#  ...]

# %% [markdown]
# ## filter classes to last 100, since fiftyone cant show more than 100 classes at once

# %%
filepaths = dataset.values('filepath')
with open('fiftyone_filepaths.txt','r') as f:
    filepaths = f.readlines()

# %%
filepaths = [i.replace('\n','') for i in filepaths]

# %%
pos_view = dataset.filter_labels("ground_truth", F("label").is_in(tuple(classes[100:])))

# %%
filtered_paths = (np.array(filepaths)[:, None] == np.array(pos_view.values('filepath'))).argmax(axis=0)

# %%
embeddings = np.load('fiftyone_embeddings.npy')
# embeddings = []
# for path in filepaths:
#     img = PIL.Image.open(path.replace('/home/pranav/embedding_classification/',''))
#     if len(img.getbands()) == 1:
#         img = img.convert("RGB")
#     transformed_img = test_transform(img)
#     embedding = model(torch.unsqueeze(transformed_img,dim=0).to(device))
#     embeddings.append(embedding.detach().cpu().numpy()[0])

# %%
filtered_embeddings = np.take(embeddings,filtered_paths,axis=0)

# %%
# Compute visualization
results = fob.compute_visualization(
    pos_view, embeddings=filtered_embeddings, seed=51, brain_key="resnet50"
)
# Out:
# Generating visualization...
# /home/pranav/embedding_classification/fiftyone_env/lib/python3.8/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# UMAP(n_jobs=1, random_state=51, verbose=True)
# Mon May  6 23:26:14 2024 Construct fuzzy simplicial set
# Mon May  6 23:26:14 2024 Finding Nearest Neighbors
# Mon May  6 23:26:14 2024 Building RP forest with 9 trees
# Mon May  6 23:26:16 2024 NN descent for 13 iterations
# 	 1  /  13
# 	 2  /  13
# 	 3  /  13
# 	 4  /  13
# 	Stopping threshold met -- exiting after 4 iterations
# Mon May  6 23:26:21 2024 Finished Nearest Neighbor Search
# Mon May  6 23:26:22 2024 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Mon May  6 23:26:27 2024 Finished embedding

# %%
session = fo.launch_app(pos_view,port=8051)
session.wait()
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:8051/?notebook=True&subscription=08af0a4a-67d1-4e4d-8b7b-4a92e1c1d220"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Notebook sessions cannot wait

# %%
import glob
images = glob.glob('CUB_200_2011/images/**/*.jpg')

# %%
len(images)
# Out:
# 11788
